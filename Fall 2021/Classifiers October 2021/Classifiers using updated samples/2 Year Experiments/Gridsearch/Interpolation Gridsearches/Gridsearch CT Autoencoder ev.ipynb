# %%
import numpy as np
import seaborn as sn
from imblearn.over_sampling import SMOTE 
import keras
from keras.utils import np_utils
from keras.layers import Input, Dense, Dropout
from keras.models import Model, Sequential
from keras import losses
from keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.utils import class_weight
from sklearn.metrics import recall_score, confusion_matrix, multilabel_confusion_matrix, precision_score, precision_recall_curve, average_precision_score, make_scorer
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from pandas import DataFrame
import xlsxwriter
import time

IBIS = pd.ExcelFile("SA_and_CT_AALandfROI_08272019.xlsx")

#Get the sheets for scaling
IBIS_CT = IBIS.sheet_names[9]
CT = IBIS.parse(IBIS_CT)

#Get rid of subject names to only have features now. #Need to remove ROIs. They don't convert to floats.
#Get rid of ctx_rh_Medial_wall and ctx_lh_Medial_wall, not needed for analysis.
#Scaling
IBIS_CT_features = CT.loc[:, CT.columns] 
IBIS_CT_features = IBIS_CT_features.drop(['Case','Visit','ROI42','ROI117'], axis=1)  
scalerCT = MinMaxScaler()
scaled_CT_data = scalerCT.fit_transform(IBIS_CT_features)

#Get the sheets for scaling
IBIS_SA = IBIS.sheet_names[10]
SA = IBIS.parse(IBIS_SA)

#Get rid of subject names to only have features now. #Need to remove ROIs. They don't convert to floats.
#Get rid of ctx_rh_Medial_wall and ctx_lh_Medial_wall, not needed for analysis.
#Scaling

IBIS_SA_features = SA.loc[:, SA.columns] 
IBIS_SA_features = IBIS_SA_features.drop(['Case','Visit','ROI42','ROI117'], axis=1)  
scalerSA = MinMaxScaler()
scaled_SA_data = scalerSA.fit_transform(IBIS_SA_features)

file = pd.ExcelFile("All CTSA 2-1yr.xlsx") #Only includes IBIS subjects that have 1,2 year CT,SA.

ct1y_sheet = file.sheet_names[0]
ct1y_data = file.parse(ct1y_sheet)
ct1y_data_features = ct1y_data.loc[:, ct1y_data.columns] 
ct1y_data_features = ct1y_data_features.drop(['ROI', 11142, 12142], axis=1)  #Already removed medial walls.

ct2y_sheet = file.sheet_names[1]
ct2y_data = file.parse(ct2y_sheet)
ct2y_data_features = ct2y_data.loc[:, ct2y_data.columns] 
ct2y_data_features = ct2y_data_features.drop(['ROI', 11142, 12142], axis=1)  #Already removed medial walls.

sa1y_sheet = file.sheet_names[2]
sa1y_data = file.parse(sa1y_sheet)
sa1y_data_features = sa1y_data.loc[:, sa1y_data.columns] 
sa1y_data_features = sa1y_data_features.drop(['ROI', 11142, 12142], axis=1)  #Already removed medial walls.

sa2y_sheet = file.sheet_names[3]
sa2y_data = file.parse(sa2y_sheet)
sa2y_data_features = sa2y_data.loc[:, sa2y_data.columns] 
sa2y_data_features = sa2y_data_features.drop(['ROI', 11142, 12142], axis=1)  #Already removed medial walls.

scaled_ct1y = scalerSA.transform(ct1y_data_features)
scaled_ct2y = scalerSA.transform(ct2y_data_features)

print(ct1y_data_features.shape)
print(ct2y_data_features.shape)
print(sa1y_data_features.shape)
print(sa2y_data_features.shape)
# Out:
# /nas/longleaf/apps/anaconda/2019.10.ood/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# (585, 148)
# (585, 148)
# (585, 148)
# (585, 148)

# %%
def create_model(dropout=0.1, layer1_size=110, layer2_size=20, encoded_layer_size=15):
    # create model
    model = Sequential()
    model.add(Dense(layer1_size, input_dim=148, activation='tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(layer2_size, activation='tanh'))
    model.add(Dense(encoded_layer_size, activation='tanh'))
    model.add(Dense(layer2_size, activation='tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(layer1_size, activation='tanh'))
    model.add(Dense(148,activation='tanh'))
    # Compile model
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
# create model
model = KerasRegressor(build_fn=create_model, verbose=0)
# define the grid search parameters
batch_size = [10, 15, 20, 25, 30]
epochs = [50, 100, 150] 
dropout_rate = [0.15, 0.2, 0.25]
#Hidden layer sizes
hidden_size1 = [90, 100, 110] 
hidden_size2 = [25, 30, 35, 40] 
encoded_layer_size_array = [15,20,25]

param_grid = dict(batch_size=batch_size, epochs=epochs, dropout=dropout_rate, layer1_size=hidden_size1, layer2_size=hidden_size2, encoded_layer_size=encoded_layer_size_array)
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring='explained_variance', n_jobs=-1, cv=5)
grid_result = grid.fit(scaled_ct1y,scaled_ct2y)
# Out:
# /nas/longleaf/apps/anaconda/2019.10.ood/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning

# %%
df = pd.DataFrame(grid_result.cv_results_)
df.to_excel("ExplainedVarianceCT.xlsx")
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
df
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0          4.325980      0.693841         0.149291        0.066292
# 1          4.294821      0.323752         0.100625        0.030303
# 2          4.206800      0.386233         0.091675        0.011198
# 3          4.392288      0.417362         0.142106        0.030337
# 4          4.130071      0.249690         0.170811        0.097510
# ...             ...           ...              ...             ...
# 1615       4.605252      0.102316         0.104073        0.022871
# 1616       4.596974      0.319319         0.082107        0.017855
# 1617       4.585129      0.144278         0.104187        0.020574
# 1618       4.592140      0.092346         0.108739        0.042424
# 1619       4.428584      0.176057         0.082795        0.025668
#
#      param_batch_size param_dropout param_encoded_layer_size param_epochs  \
# 0                  10          0.15                       15           50
# 1                  10          0.15                       15           50
# 2                  10          0.15                       15           50
# 3                  10          0.15                       15           50
# 4                  10          0.15                       15           50
# ...               ...           ...                      ...          ...
# 1615               30          0.25                       25          150
# 1616               30          0.25                       25          150
# 1617               30          0.25                       25          150
# 1618               30          0.25                       25          150
# 1619               30          0.25                       25          150
#
#      param_layer1_size param_layer2_size  \
# 0                   90                25
# 1                   90                30
# 2                   90                35
# 3                   90                40
# 4                  100                25
# ...                ...               ...
# 1615               100                40
# 1616               110                25
# 1617               110                30
# 1618               110                35
# 1619               110                40
#
#                                                  params  split0_test_score  \
# 0     {'batch_size': 10, 'dropout': 0.15, 'encoded_l...          -0.994770
# 1     {'batch_size': 10, 'dropout': 0.15, 'encoded_l...          -0.946581
# 2     {'batch_size': 10, 'dropout': 0.15, 'encoded_l...          -0.615024
# 3     {'batch_size': 10, 'dropout': 0.15, 'encoded_l...          -0.567883
# 4     {'batch_size': 10, 'dropout': 0.15, 'encoded_l...          -1.101774
# ...                                                 ...                ...
# 1615  {'batch_size': 30, 'dropout': 0.25, 'encoded_l...          -0.478896
# 1616  {'batch_size': 30, 'dropout': 0.25, 'encoded_l...          -0.530110
# 1617  {'batch_size': 30, 'dropout': 0.25, 'encoded_l...          -0.335339
# 1618  {'batch_size': 30, 'dropout': 0.25, 'encoded_l...          -0.840092
# 1619  {'batch_size': 30, 'dropout': 0.25, 'encoded_l...          -0.465731
#
#       split1_test_score  split2_test_score  split3_test_score  \
# 0             -0.837802           0.184736          -1.039623
# 1             -0.651016           0.102750          -0.618222
# 2             -1.094183           0.345948          -0.521842
# 3             -1.218443          -0.269972          -0.636195
# 4             -0.723681          -0.213353          -1.028486
# ...                 ...                ...                ...
# 1615          -0.402267           0.349601          -1.280907
# 1616          -0.464780           0.410401          -0.383591
# 1617          -0.470338           0.187936          -0.453949
# 1618          -0.576961           0.105631          -0.247713
# 1619          -0.580644           0.415090          -0.260571
#
#       split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0
with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 25}
# -0.396891 (0.540669) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 30}
# -0.255512 (0.208996) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 35}
# -0.137672 (0.259399) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 40}
# -0.459587 (0.508803) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 25}
# -0.371007 (0.383487) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 30}
# -0.397645 (0.463894) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 35}
# -0.217734 (0.309458) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 40}
# -0.893200 (0.632614) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 25}
# -0.531008 (0.398880) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 30}
# -0.546910 (0.472511) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 35}
# -0.528759 (0.443385) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 40}
# -0.395882 (0.410896) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 25}
# -0.389626 (0.347458) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 30}
# -0.362219 (0.429985) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 35}
# -0.437884 (0.483334) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 40}
# -0.464333 (0.114740) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 25}
# -0.289526 (0.299045) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 30}
# -0.321816 (0.402170) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 35}
# -0.556658 (0.638639) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 40}
# -0.491639 (0.407337) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 25}
# -0.560450 (0.651137) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 30}
# -0.633139 (0.579206) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 35}
# -0.393301 (0.100049) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 40}
# -0.477306 (0.536495) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 25}
# -0.453077 (0.553455) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 30}
# -0.428691 (0.481531) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 35}
# -0.482186 (0.556796) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 40}
# -0.364003 (0.464139) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 25}
# -0.371955 (0.483833) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 30}
# -0.410300 (0.459696) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 35}
# -0.410295 (0.490356) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 40}
# -0.286000 (0.391656) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 25}
# -0.356045 (0.431302) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 30}
# -0.360399 (0.500021) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 35}
# -0.408241 (0.489211) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 40}
# -0.484634 (0.266383) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 25}
# -0.347738 (0.379814) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 30}
# -0.321752 (0.385458) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 35}
# -0.230933 (0.334015) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 40}
# -0.469017 (0.343240) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 25}
# -0.624860 (0.527060) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 30}
# -0.384946 (0.384783) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 35}
# -0.550313 (0.753944) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 40}
# -0.628357 (0.509725) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 25}
# -0.454927 (0.445011) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 30}
# -0.580926 (0.644274) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 35}
# -0.365467 (0.342970) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 40}
# -0.570710 (0.465317) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 25}
# -0.352722 (0.421668) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 30}
# -0.347937 (0.448661) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 35}
# -0.345912 (0.435382) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 40}
# -0.400060 (0.307240) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 25}
# -0.314825 (0.411162) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 30}
# -0.224974 (0.311055) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 35}
# -0.416837 (0.375338) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 40}
# -0.391017 (0.298127) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 25}
# -0.511807 (0.426077) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 30}
# -0.437717 (0.362493) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 35}
# -0.349108 (0.387667) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 40}
# -0.439518 (0.555310) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 25}
# -0.620179 (0.610065) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 30}
# -0.634468 (0.604937) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 35}
# -0.558012 (0.525758) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 40}
# -0.359681 (0.443058) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 25}
# -0.473676 (0.521854) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 30}
# -0.603647 (0.517922) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 35}
# -0.488541 (0.517433) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 40}
# -0.278150 (0.405636) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 25}
# -0.356035 (0.378733) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 30}
# -0.581171 (0.628162) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 35}
# -0.494422 (0.451037) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 40}
# -0.423705 (0.359033) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 25}
# -0.435902 (0.473360) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 30}
# -0.370108 (0.430005) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 35}
# -0.544312 (0.405082) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 40}
# -0.520381 (0.500254) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 25}
# -0.640805 (0.682755) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 30}
# -0.485768 (0.284070) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 35}
# -0.368227 (0.512372) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 40}
# -0.501099 (0.249922) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 25}
# -0.635490 (0.403176) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 30}
# -0.507629 (0.427855) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 35}
# -0.564555 (0.587233) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 40}
# -0.447770 (0.358707) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 25}
# -0.444427 (0.441365) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 30}
# -0.434152 (0.444552) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 35}
# -0.302569 (0.403195) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 40}
# -0.682101 (0.543419) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 25}
# -0.565719 (0.562394) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 30}
# -0.578394 (0.322066) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 35}
# -0.478583 (0.518809) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 40}
# -0.615040 (0.819901) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 25}
# -0.299776 (0.248283) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 30}
# -0.342198 (0.331277) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 35}
# -0.261890 (0.353752) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 40}
