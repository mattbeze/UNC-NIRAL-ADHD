# %%
import numpy as np
import seaborn as sn
from imblearn.over_sampling import SMOTE 
import keras
from keras.utils import np_utils
from keras.layers import Input, Dense, Dropout
from keras.models import Model, Sequential
from keras import losses
from keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.utils import class_weight
from sklearn.metrics import recall_score, confusion_matrix, multilabel_confusion_matrix, precision_score, precision_recall_curve, average_precision_score, make_scorer
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from pandas import DataFrame
import xlsxwriter
import time

IBIS = pd.ExcelFile("SA_and_CT_AALandfROI_08272019.xlsx")

#Get the sheets for scaling
IBIS_CT = IBIS.sheet_names[9]
CT = IBIS.parse(IBIS_CT)

#Get rid of subject names to only have features now. #Need to remove ROIs. They don't convert to floats.
#Get rid of ctx_rh_Medial_wall and ctx_lh_Medial_wall, not needed for analysis.
#Scaling
IBIS_CT_features = CT.loc[:, CT.columns] 
IBIS_CT_features = IBIS_CT_features.drop(['Case','Visit','ROI42','ROI117'], axis=1)  
scalerCT = MinMaxScaler()
scaled_CT_data = scalerCT.fit_transform(IBIS_CT_features)

#Get the sheets for scaling
IBIS_SA = IBIS.sheet_names[10]
SA = IBIS.parse(IBIS_SA)

#Get rid of subject names to only have features now. #Need to remove ROIs. They don't convert to floats.
#Get rid of ctx_rh_Medial_wall and ctx_lh_Medial_wall, not needed for analysis.
#Scaling

IBIS_SA_features = SA.loc[:, SA.columns] 
IBIS_SA_features = IBIS_SA_features.drop(['Case','Visit','ROI42','ROI117'], axis=1)  
scalerSA = MinMaxScaler()
scaled_SA_data = scalerSA.fit_transform(IBIS_SA_features)

file = pd.ExcelFile("All CTSA 2-1yr.xlsx") #Only includes IBIS subjects that have 1,2 year CT,SA.

ct1y_sheet = file.sheet_names[0]
ct1y_data = file.parse(ct1y_sheet)
ct1y_data_features = ct1y_data.loc[:, ct1y_data.columns] 
ct1y_data_features = ct1y_data_features.drop(['ROI', 11142, 12142], axis=1)  #Already removed medial walls.

ct2y_sheet = file.sheet_names[1]
ct2y_data = file.parse(ct2y_sheet)
ct2y_data_features = ct2y_data.loc[:, ct2y_data.columns] 
ct2y_data_features = ct2y_data_features.drop(['ROI', 11142, 12142], axis=1)  #Already removed medial walls.

sa1y_sheet = file.sheet_names[2]
sa1y_data = file.parse(sa1y_sheet)
sa1y_data_features = sa1y_data.loc[:, sa1y_data.columns] 
sa1y_data_features = sa1y_data_features.drop(['ROI', 11142, 12142], axis=1)  #Already removed medial walls.

sa2y_sheet = file.sheet_names[3]
sa2y_data = file.parse(sa2y_sheet)
sa2y_data_features = sa2y_data.loc[:, sa2y_data.columns] 
sa2y_data_features = sa2y_data_features.drop(['ROI', 11142, 12142], axis=1)  #Already removed medial walls.

scaled_sa1y = scalerSA.transform(sa1y_data_features)
scaled_sa2y = scalerSA.transform(sa2y_data_features)

print(ct1y_data_features.shape)
print(ct2y_data_features.shape)
print(sa1y_data_features.shape)
print(sa2y_data_features.shape)
# Out:
# /nas/longleaf/apps/anaconda/2019.10.ood/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# (585, 148)
# (585, 148)
# (585, 148)
# (585, 148)

# %%
def create_model(dropout=0.1, layer1_size=110, layer2_size=20, encoded_layer_size=15):
    # create model
    model = Sequential()
    model.add(Dense(layer1_size, input_dim=148, activation='tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(layer2_size, activation='tanh'))
    model.add(Dense(encoded_layer_size, activation='tanh'))
    model.add(Dense(layer2_size, activation='tanh'))
    model.add(Dropout(dropout))
    model.add(Dense(layer1_size, activation='tanh'))
    model.add(Dense(148,activation='tanh'))
    # Compile model
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
# create model
model = KerasRegressor(build_fn=create_model, verbose=0)
# define the grid search parameters
batch_size = [10, 15, 20, 25, 30]
epochs = [50, 100, 150] 
dropout_rate = [0.15, 0.2, 0.25]
#Hidden layer sizes
hidden_size1 = [90, 100, 110] 
hidden_size2 = [25, 30, 35, 40] 
encoded_layer_size_array = [15,20,25]

param_grid = dict(batch_size=batch_size, epochs=epochs, dropout=dropout_rate, layer1_size=hidden_size1, layer2_size=hidden_size2, encoded_layer_size=encoded_layer_size_array)
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring='explained_variance', n_jobs=-1, cv=5)
grid_result = grid.fit(scaled_sa1y,scaled_sa2y)
# Out:
# /nas/longleaf/apps/anaconda/2019.10.ood/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning

# %%
df = pd.DataFrame(grid_result.cv_results_)
df.to_excel("ExplainedVarianceSA.xlsx")
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
df
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0          3.575743      0.591770         0.139092        0.053178
# 1          3.657822      0.612879         0.088950        0.031779
# 2          3.313345      0.660011         0.087349        0.017862
# 3          3.254322      0.281668         0.103255        0.044617
# 4          3.358313      0.431412         0.099653        0.024900
# ...             ...           ...              ...             ...
# 1615       4.223694      0.683361         0.238470        0.186815
# 1616       3.729555      0.490881         0.319819        0.305988
# 1617       4.045702      0.667519         0.079663        0.010730
# 1618       4.177370      0.723362         0.083508        0.031678
# 1619       4.047127      0.862373         0.065277        0.011398
#
#      param_batch_size param_dropout param_encoded_layer_size param_epochs  \
# 0                  10          0.15                       15           50
# 1                  10          0.15                       15           50
# 2                  10          0.15                       15           50
# 3                  10          0.15                       15           50
# 4                  10          0.15                       15           50
# ...               ...           ...                      ...          ...
# 1615               30          0.25                       25          150
# 1616               30          0.25                       25          150
# 1617               30          0.25                       25          150
# 1618               30          0.25                       25          150
# 1619               30          0.25                       25          150
#
#      param_layer1_size param_layer2_size  \
# 0                   90                25
# 1                   90                30
# 2                   90                35
# 3                   90                40
# 4                  100                25
# ...                ...               ...
# 1615               100                40
# 1616               110                25
# 1617               110                30
# 1618               110                35
# 1619               110                40
#
#                                                  params  split0_test_score  \
# 0     {'batch_size': 10, 'dropout': 0.15, 'encoded_l...           0.196688
# 1     {'batch_size': 10, 'dropout': 0.15, 'encoded_l...           0.195237
# 2     {'batch_size': 10, 'dropout': 0.15, 'encoded_l...           0.198398
# 3     {'batch_size': 10, 'dropout': 0.15, 'encoded_l...           0.209859
# 4     {'batch_size': 10, 'dropout': 0.15, 'encoded_l...           0.184778
# ...                                                 ...                ...
# 1615  {'batch_size': 30, 'dropout': 0.25, 'encoded_l...           0.249051
# 1616  {'batch_size': 30, 'dropout': 0.25, 'encoded_l...           0.211438
# 1617  {'batch_size': 30, 'dropout': 0.25, 'encoded_l...           0.226717
# 1618  {'batch_size': 30, 'dropout': 0.25, 'encoded_l...           0.226987
# 1619  {'batch_size': 30, 'dropout': 0.25, 'encoded_l...           0.245335
#
#       split1_test_score  split2_test_score  split3_test_score  \
# 0              0.158164           0.206003           0.190542
# 1              0.164777           0.197728           0.206465
# 2              0.162216           0.214009           0.194509
# 3              0.183095           0.222322           0.209193
# 4              0.160715           0.193325           0.197979
# ...                 ...                ...                ...
# 1615           0.221985           0.257978           0.256137
# 1616           0.210376           0.232082           0.224253
# 1617           0.217064           0.254326           0.239935
# 1618           0.214016           0.254802           0.244833
# 1619           0.219186           0.266932           0.245392
#
#       split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0              0.208612         0.192002        0.018117             1185
# 1              0.213689         0.195579        0.016733             1153
# 2              0.205821         0.194991        0.017692             1158
# 3              0.217953         0.208484        0.013624              992
# 4              0.200384         0.187436        0.014384             1227
# ...                 ...              ...             ...              ...
# 1615           0.251058         0.247242        0.013039              193
# 1616           0.230996         0.221829        0.009319              742
# 1617           0.242761         0.236160        0.012974              386
# 1618           0.242968         0.236721        0.014436              372
# 1619           0.244141         0.244197        0.015134              240
#
# [1620 rows x 19 columns]

# %%
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.273633 using {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 40}
# 0.192002 (0.018117) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 25}
# 0.195579 (0.016733) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 30}
# 0.194991 (0.017692) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 35}
# 0.208484 (0.013624) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 40}
# 0.187436 (0.014384) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 25}
# 0.196840 (0.014306) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 30}
# 0.198722 (0.013146) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 35}
# 0.205266 (0.017856) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 40}
# 0.192599 (0.015447) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 25}
# 0.195985 (0.019428) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 30}
# 0.202074 (0.011174) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 35}
# 0.205911 (0.012926) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 40}
# 0.220220 (0.015516) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 25}
# 0.224860 (0.012186) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 30}
# 0.227138 (0.013474) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 35}
# 0.230586 (0.008055) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 40}
# 0.228594 (0.014289) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 25}
# 0.223750 (0.012306) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 30}
# 0.226879 (0.009609) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 35}
# 0.227045 (0.012805) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 40}
# 0.220339 (0.014624) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 25}
# 0.225730 (0.014914) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 30}
# 0.227619 (0.012293) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 35}
# 0.232265 (0.014860) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 40}
# 0.229757 (0.011932) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 25}
# 0.232211 (0.014441) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 30}
# 0.235081 (0.011250) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 35}
# 0.235971 (0.012703) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 40}
# 0.230034 (0.009939) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 25}
# 0.232500 (0.010735) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 30}
# 0.231538 (0.014861) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 35}
# 0.232851 (0.014967) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 40}
# 0.230472 (0.013098) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 25}
# 0.231128 (0.013405) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 30}
# 0.232109 (0.008228) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 35}
# 0.233429 (0.014616) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 40}
# 0.189568 (0.013108) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 25}
# 0.205334 (0.016434) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 30}
# 0.207956 (0.015230) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 35}
# 0.210829 (0.020447) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 40}
# 0.199858 (0.015580) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 25}
# 0.201000 (0.013063) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 30}
# 0.220696 (0.018828) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 35}
# 0.217937 (0.011693) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 40}
# 0.197405 (0.017490) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 25}
# 0.207137 (0.021709) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 30}
# 0.211343 (0.015116) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 35}
# 0.223036 (0.010691) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 40}
# 0.226760 (0.013321) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 25}
# 0.241540 (0.011542) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 30}
# 0.246756 (0.010474) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 35}
# 0.248958 (0.011730) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 40}
# 0.230176 (0.012829) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 25}
# 0.235451 (0.013833) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 30}
# 0.246345 (0.008392) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 35}
# 0.248363 (0.011753) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 40}
# 0.229544 (0.012603) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 25}
# 0.240025 (0.010343) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 30}
# 0.244520 (0.014553) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 35}
# 0.243686 (0.018743) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 40}
# 0.246833 (0.011353) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 25}
# 0.253291 (0.014653) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 30}
# 0.258396 (0.011623) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 35}
# 0.255046 (0.016821) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 40}
# 0.247616 (0.008726) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 25}
# 0.248115 (0.011888) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 30}
# 0.252917 (0.010249) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 35}
# 0.252325 (0.017950) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 40}
# 0.241930 (0.010416) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 25}
# 0.248425 (0.018258) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 30}
# 0.251271 (0.014495) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 35}
# 0.253890 (0.012088) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 40}
# 0.199893 (0.018697) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 25}
# 0.209383 (0.012585) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 30}
# 0.219251 (0.017800) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 35}
# 0.225963 (0.014926) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 40}
# 0.205569 (0.015114) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 25}
# 0.207023 (0.009710) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 30}
# 0.225530 (0.016307) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 35}
# 0.213153 (0.017966) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 40}
# 0.201748 (0.016129) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 25}
# 0.213190 (0.015321) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 30}
# 0.225642 (0.008795) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 35}
# 0.233276 (0.014173) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 40}
# 0.237720 (0.014853) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 25}
# 0.251745 (0.012239) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 30}
# 0.259107 (0.013020) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 35}
# 0.264312 (0.014691) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 40}
# 0.246168 (0.012431) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 25}
# 0.249437 (0.012168) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 30}
# 0.256209 (0.014149) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 35}
# 0.263072 (0.013471) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 40}
# 0.239166 (0.012709) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 25}
# 0.248511 (0.014586) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 30}
# 0.257806 (0.017037) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 35}
# 0.264370 (0.013726) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 40}
# 0.250812 (0.006756) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 25}
# 0.263325 (0.013176) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 30}
# 0.273517 (0.011065) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 35}
# 0.273058 (0.013135) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 40}
# 0.252273 (0.015279) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 25}
# 0.262985 (0.016355) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 30}
# 0.267970 (0.014170) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 35}
# 0.273633 (0.014793) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 40}
# 0.255726 (0.012616) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 25}
# 0.264840 (0.013008) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 30}
# 0.271013 (0.011938) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 35}
# 0.272709 (0.012573) with: {'batch_size': 10, 'dropout': 0.15, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 40}
# 0.179212 (0.009498) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 25}
# 0.190573 (0.015996) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 30}
# 0.191590 (0.015077) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 35}
# 0.195669 (0.012360) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 40}
# 0.183138 (0.013048) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 25}
# 0.190478 (0.014245) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 30}
# 0.194829 (0.015320) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 35}
# 0.197104 (0.017274) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 40}
# 0.185955 (0.014586) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 25}
# 0.190987 (0.011558) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 30}
# 0.191940 (0.009295) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 35}
# 0.205369 (0.017559) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 40}
# 0.214880 (0.017316) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 25}
# 0.224271 (0.019952) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 30}
# 0.225820 (0.014622) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 35}
# 0.232305 (0.013811) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 40}
# 0.211592 (0.011919) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 25}
# 0.213708 (0.015924) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 30}
# 0.228616 (0.010813) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 35}
# 0.225299 (0.011300) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 40}
# 0.218216 (0.014634) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 25}
# 0.222597 (0.007178) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 30}
# 0.222960 (0.013077) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 35}
# 0.219392 (0.009952) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 40}
# 0.229408 (0.009228) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 25}
# 0.232389 (0.013007) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 30}
# 0.231073 (0.014808) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 35}
# 0.234725 (0.011726) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 40}
# 0.224859 (0.015054) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 25}
# 0.230201 (0.012737) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 30}
# 0.233237 (0.012181) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 35}
# 0.234344 (0.010650) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 40}
# 0.228217 (0.008342) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 25}
# 0.231421 (0.009473) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 30}
# 0.229207 (0.011662) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 35}
# 0.232049 (0.016191) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 40}
# 0.189108 (0.017578) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 25}
# 0.201285 (0.010825) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 30}
# 0.202901 (0.017609) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 35}
# 0.207159 (0.017062) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 40}
# 0.180846 (0.019476) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 25}
# 0.196499 (0.009118) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 30}
# 0.207614 (0.013091) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 35}
# 0.214198 (0.012433) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 40}
# 0.196472 (0.018840) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 25}
# 0.192587 (0.018190) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 30}
# 0.209223 (0.018254) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 35}
# 0.218057 (0.018731) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 40}
# 0.223052 (0.009040) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 25}
# 0.233430 (0.010181) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 30}
# 0.245705 (0.014625) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 35}
# 0.242841 (0.015072) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 40}
# 0.227845 (0.009816) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 25}
# 0.231373 (0.016750) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 30}
# 0.241513 (0.012408) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 35}
# 0.245908 (0.014680) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 40}
# 0.223566 (0.019373) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 25}
# 0.230297 (0.015102) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 30}
# 0.241112 (0.013138) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 35}
# 0.242338 (0.013071) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 40}
# 0.242267 (0.014168) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 25}
# 0.246165 (0.014971) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 30}
# 0.255170 (0.011480) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 35}
# 0.255194 (0.009581) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 40}
# 0.238124 (0.010717) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 25}
# 0.248424 (0.011271) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 30}
# 0.253230 (0.013204) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 35}
# 0.254016 (0.011199) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 40}
# 0.241770 (0.009022) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 25}
# 0.243085 (0.012046) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 30}
# 0.249215 (0.006888) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 35}
# 0.252921 (0.013827) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 40}
# 0.192120 (0.019356) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 25}
# 0.201003 (0.016807) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 30}
# 0.205448 (0.009763) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 35}
# 0.217640 (0.022202) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 40}
# 0.189339 (0.014064) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 25}
# 0.207127 (0.011748) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 30}
# 0.210194 (0.018025) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 35}
# 0.216272 (0.014405) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 40}
# 0.198206 (0.008288) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 25}
# 0.206934 (0.009471) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 30}
# 0.209117 (0.015434) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 35}
# 0.221660 (0.017218) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 40}
# 0.230118 (0.014749) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 25}
# 0.242419 (0.008742) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 30}
# 0.250944 (0.014027) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 35}
# 0.259284 (0.014964) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 40}
# 0.236345 (0.009907) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 25}
# 0.243213 (0.012116) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 30}
# 0.249343 (0.013581) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 35}
# 0.256801 (0.015003) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 40}
# 0.232252 (0.017694) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 25}
# 0.244320 (0.011430) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 30}
# 0.253114 (0.013055) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 35}
# 0.256085 (0.008703) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 40}
# 0.249830 (0.013516) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 25}
# 0.262447 (0.012114) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 30}
# 0.262938 (0.013545) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 35}
# 0.271843 (0.011588) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 40}
# 0.243704 (0.011007) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 25}
# 0.260487 (0.008563) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 30}
# 0.263517 (0.018917) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 35}
# 0.272422 (0.014454) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 40}
# 0.249176 (0.006848) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 25}
# 0.261151 (0.010191) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 30}
# 0.260920 (0.014791) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 35}
# 0.270183 (0.013427) with: {'batch_size': 10, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 40}
# 0.177298 (0.006087) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 25}
# 0.183889 (0.014607) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 30}
# 0.182515 (0.013428) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 35}
# 0.190422 (0.017287) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 40}
# 0.177505 (0.009226) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 25}
# 0.174832 (0.007669) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 30}
# 0.194155 (0.015066) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 35}
# 0.192454 (0.014786) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 40}
# 0.174141 (0.020863) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 25}
# 0.183226 (0.010944) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 30}
# 0.189429 (0.014634) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 35}
# 0.197884 (0.007350) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 40}
# 0.212544 (0.014544) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 25}
# 0.214739 (0.007211) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 30}
# 0.218457 (0.020485) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 35}
# 0.214469 (0.014184) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 40}
# 0.213383 (0.012498) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 25}
# 0.210987 (0.014523) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 30}
# 0.219731 (0.011858) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 35}
# 0.216030 (0.010779) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 40}
# 0.215728 (0.011106) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 25}
# 0.211379 (0.009156) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 30}
# 0.216033 (0.009514) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 35}
# 0.218997 (0.015343) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 40}
# 0.223728 (0.010651) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 25}
# 0.226951 (0.011097) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 30}
# 0.232643 (0.007592) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 35}
# 0.233022 (0.009696) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 40}
# 0.222228 (0.009882) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 25}
# 0.226110 (0.010372) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 30}
# 0.230355 (0.008398) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 35}
# 0.232638 (0.011388) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 40}
# 0.225328 (0.008231) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 25}
# 0.226191 (0.010836) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 30}
# 0.227824 (0.010996) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 35}
# 0.228691 (0.010886) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 40}
# 0.178144 (0.010104) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 25}
# 0.185931 (0.017021) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 30}
# 0.187301 (0.016133) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 35}
# 0.198740 (0.018464) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 40}
# 0.180138 (0.013178) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 25}
# 0.188303 (0.014134) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 30}
# 0.194487 (0.017303) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 35}
# 0.198550 (0.012812) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 40}
# 0.179330 (0.019326) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 25}
# 0.190906 (0.007720) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 30}
# 0.197406 (0.007748) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 35}
# 0.204313 (0.011735) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 40}
# 0.222565 (0.011879) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 25}
# 0.231065 (0.016885) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 30}
# 0.235573 (0.009135) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 35}
# 0.242711 (0.016775) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 40}
# 0.216009 (0.010970) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 25}
# 0.229611 (0.016503) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 30}
# 0.232312 (0.013670) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 35}
# 0.234646 (0.012226) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 40}
# 0.215180 (0.010900) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 25}
# 0.225163 (0.011837) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 30}
# 0.234432 (0.013073) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 35}
# 0.239011 (0.010927) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 40}
# 0.236395 (0.008004) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 25}
# 0.245025 (0.010920) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 30}
# 0.252271 (0.012719) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 35}
# 0.245976 (0.015270) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 40}
# 0.238461 (0.013001) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 25}
# 0.244450 (0.011795) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 30}
# 0.245692 (0.009180) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 35}
# 0.252901 (0.012169) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 40}
# 0.227299 (0.013729) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 25}
# 0.241750 (0.015489) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 30}
# 0.247604 (0.009586) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 35}
# 0.250374 (0.009124) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 40}
# 0.185288 (0.015149) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 25}
# 0.192013 (0.009020) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 30}
# 0.196491 (0.019457) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 35}
# 0.201555 (0.012956) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 40}
# 0.183249 (0.014715) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 25}
# 0.189688 (0.013990) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 30}
# 0.204094 (0.013605) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 35}
# 0.210707 (0.015955) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 40}
# 0.191979 (0.013502) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 25}
# 0.196717 (0.014126) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 30}
# 0.197857 (0.019710) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 35}
# 0.198702 (0.020738) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 40}
# 0.227717 (0.008346) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 25}
# 0.234974 (0.009655) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 30}
# 0.243679 (0.006838) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 35}
# 0.246828 (0.010978) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 40}
# 0.225527 (0.011738) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 25}
# 0.235759 (0.008212) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 30}
# 0.242644 (0.011715) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 35}
# 0.252577 (0.013992) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 40}
# 0.223882 (0.010991) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 25}
# 0.238577 (0.013919) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 30}
# 0.239300 (0.019088) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 35}
# 0.247888 (0.013463) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 40}
# 0.241460 (0.007785) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 25}
# 0.252981 (0.012473) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 30}
# 0.256527 (0.010198) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 35}
# 0.263932 (0.013075) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 40}
# 0.242860 (0.010090) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 25}
# 0.250207 (0.013496) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 30}
# 0.259336 (0.010862) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 35}
# 0.265505 (0.015119) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 40}
# 0.241332 (0.013190) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 25}
# 0.251091 (0.012082) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 30}
# 0.257402 (0.012082) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 35}
# 0.263567 (0.009750) with: {'batch_size': 10, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 40}
# 0.173233 (0.017264) with: {'batch_size': 15, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 25}
# 0.176952 (0.015526) with: {'batch_size': 15, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 30}
# 0.183253 (0.016740) with: {'batch_size': 15, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 35}
# 0.188302 (0.018519) with: {'batch_size': 15, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 40}
# 0.178269 (0.013415) with: {'batch_size': 15, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 25}
# 0.182995 (0.016693) with: {'batch_size': 15, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 30}
# 0.188298 (0.011744) with: {'batch_size': 15, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 35}
# 0.195646 (0.012506) with: {'batch_size': 15, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 40}
# 0.181173 (0.016105) with: {'batch_size': 15, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 25}
# 0.184408 (0.014144) with: {'batch_size': 15, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 30}
# 0.194576 (0.016448) with: {'batch_size': 15, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 35}
# 0.199752 (0.007828) with: {'batch_size': 15, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 40}
# 0.210356 (0.016594) with: {'batch_size': 15, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 25}
# 0.222046 (0.016129) with: {'batch_size': 15, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 30}
# 0.219711 (0.012775) with: {'batch_size': 15, 'dropout': 0.15, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 35}
# ...
# 0.251150 (0.017735) with: {'batch_size': 30, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 40}
# 0.233588 (0.010430) with: {'batch_size': 30, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 25}
# 0.244109 (0.012595) with: {'batch_size': 30, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 30}
# 0.249005 (0.021883) with: {'batch_size': 30, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 35}
# 0.254305 (0.014753) with: {'batch_size': 30, 'dropout': 0.2, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 40}
# 0.136266 (0.013040) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 25}
# 0.138549 (0.015094) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 30}
# 0.140650 (0.019483) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 35}
# 0.146730 (0.024008) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 40}
# 0.138466 (0.008981) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 25}
# 0.145834 (0.015120) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 30}
# 0.144385 (0.015728) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 35}
# 0.150806 (0.021256) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 40}
# 0.138718 (0.007728) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 25}
# 0.151197 (0.015321) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 30}
# 0.150732 (0.021272) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 35}
# 0.156459 (0.018154) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 40}
# 0.183326 (0.015082) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 25}
# 0.194700 (0.017541) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 30}
# 0.203966 (0.018322) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 35}
# 0.197308 (0.017496) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 40}
# 0.189261 (0.009247) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 25}
# 0.189487 (0.013171) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 30}
# 0.192572 (0.015447) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 35}
# 0.209991 (0.008616) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 40}
# 0.186400 (0.017494) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 25}
# 0.197101 (0.012155) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 30}
# 0.193522 (0.007722) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 35}
# 0.202983 (0.018849) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 40}
# 0.212688 (0.014113) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 25}
# 0.214768 (0.016219) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 30}
# 0.218291 (0.005823) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 35}
# 0.221510 (0.016011) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 40}
# 0.203386 (0.013173) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 25}
# 0.211607 (0.011501) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 30}
# 0.218475 (0.020243) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 35}
# 0.221760 (0.012328) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 40}
# 0.207737 (0.009938) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 25}
# 0.216840 (0.017118) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 30}
# 0.220470 (0.008905) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 35}
# 0.221861 (0.011205) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 15, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 40}
# 0.134206 (0.017736) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 25}
# 0.139820 (0.009495) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 30}
# 0.152221 (0.021702) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 35}
# 0.159163 (0.012311) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 40}
# 0.140968 (0.013445) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 25}
# 0.142094 (0.014599) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 30}
# 0.151524 (0.015899) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 35}
# 0.157000 (0.011654) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 40}
# 0.142055 (0.007872) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 25}
# 0.156628 (0.007422) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 30}
# 0.156696 (0.014725) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 35}
# 0.163567 (0.015256) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 40}
# 0.187798 (0.015110) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 25}
# 0.195972 (0.013214) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 30}
# 0.200821 (0.020098) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 35}
# 0.202688 (0.016327) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 40}
# 0.197905 (0.005409) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 25}
# 0.198484 (0.016606) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 30}
# 0.200192 (0.019032) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 35}
# 0.212411 (0.015570) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 40}
# 0.191193 (0.011218) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 25}
# 0.197869 (0.014246) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 30}
# 0.203853 (0.013832) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 35}
# 0.209309 (0.016001) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 40}
# 0.211197 (0.012689) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 25}
# 0.224624 (0.010842) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 30}
# 0.232033 (0.015431) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 35}
# 0.234581 (0.012050) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 40}
# 0.215341 (0.011447) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 25}
# 0.221105 (0.007454) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 30}
# 0.230962 (0.016423) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 35}
# 0.234455 (0.016582) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 40}
# 0.219839 (0.008511) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 25}
# 0.228415 (0.010691) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 30}
# 0.230131 (0.014443) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 35}
# 0.241060 (0.014820) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 20, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 40}
# 0.134083 (0.011948) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 25}
# 0.145412 (0.018781) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 30}
# 0.149436 (0.016293) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 35}
# 0.158919 (0.013196) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 90, 'layer2_size': 40}
# 0.144344 (0.013269) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 25}
# 0.155249 (0.020058) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 30}
# 0.152402 (0.011651) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 35}
# 0.170376 (0.012073) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 100, 'layer2_size': 40}
# 0.139610 (0.014531) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 25}
# 0.150624 (0.012777) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 30}
# 0.159572 (0.014228) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 35}
# 0.160896 (0.022828) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 50, 'layer1_size': 110, 'layer2_size': 40}
# 0.192418 (0.012160) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 25}
# 0.205836 (0.011843) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 30}
# 0.205357 (0.012789) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 35}
# 0.214245 (0.010952) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 90, 'layer2_size': 40}
# 0.189564 (0.012305) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 25}
# 0.207677 (0.018073) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 30}
# 0.213510 (0.013900) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 35}
# 0.220750 (0.013850) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 100, 'layer2_size': 40}
# 0.192939 (0.020662) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 25}
# 0.202000 (0.017830) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 30}
# 0.211481 (0.017650) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 35}
# 0.223191 (0.010691) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 100, 'layer1_size': 110, 'layer2_size': 40}
# 0.223730 (0.014339) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 25}
# 0.231181 (0.014146) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 30}
# 0.238338 (0.010769) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 35}
# 0.246053 (0.011349) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 90, 'layer2_size': 40}
# 0.223620 (0.013233) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 25}
# 0.234119 (0.010340) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 30}
# 0.244481 (0.010586) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 35}
# 0.247242 (0.013039) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 100, 'layer2_size': 40}
# 0.221829 (0.009319) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 25}
# 0.236160 (0.012974) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 30}
# 0.236721 (0.014436) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 35}
# 0.244197 (0.015134) with: {'batch_size': 30, 'dropout': 0.25, 'encoded_layer_size': 25, 'epochs': 150, 'layer1_size': 110, 'layer2_size': 40}
