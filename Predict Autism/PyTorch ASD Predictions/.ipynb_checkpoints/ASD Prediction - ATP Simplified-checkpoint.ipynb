# %%
#COMET ML API KEY YarDlAXZLHepLKBFlSPyWbDPt
'''import comet_ml
comet_ml.config.save(api_key="YarDlAXZLHepLKBFlSPyWbDPt")
from comet_ml import Experiment
experiment = Experiment(
    api_key="YarDlAXZLHepLKBFlSPyWbDPt",
    project_name="asd-pytorch-atp-c",
    workspace="mattbeze",
    auto_metric_logging=True,
    auto_param_logging=True,
    auto_histogram_weight_logging=True,
    auto_histogram_gradient_logging=True,
    auto_histogram_activation_logging=True,
)
hyper_params = {
    "input_size": 298,
    "hidden_size1": 100,
    "hidden_size2": 15,
    "num_layers": 4,
    "num_classes": 2,
    "batch_size": 35,
    "num_epochs": 50,
    "learning_rate": 0.01
}
experiment.log_parameters(hyper_params)'''
# Out:
# 'import comet_ml\ncomet_ml.config.save(api_key="YarDlAXZLHepLKBFlSPyWbDPt")\nfrom comet_ml import Experiment\nexperiment = Experiment(\n    api_key="YarDlAXZLHepLKBFlSPyWbDPt",\n    project_name="asd-pytorch-atp-c",\n    workspace="mattbeze",\n    auto_metric_logging=True,\n    auto_param_logging=True,\n    auto_histogram_weight_logging=True,\n    auto_histogram_gradient_logging=True,\n    auto_histogram_activation_logging=True,\n)\nhyper_params = {\n    "input_size": 298,\n    "hidden_size1": 100,\n    "hidden_size2": 15,\n    "num_layers": 4,\n    "num_classes": 2,\n    "batch_size": 35,\n    "num_epochs": 50,\n    "learning_rate": 0.01\n}\nexperiment.log_parameters(hyper_params)'

# %%
import seaborn as sn
from imblearn.over_sampling import SMOTE 
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.utils import class_weight
from sklearn.metrics import accuracy_score, recall_score, confusion_matrix, multilabel_confusion_matrix, precision_score, precision_recall_curve, average_precision_score, classification_report
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from torch.utils.data import Dataset, DataLoader, random_split
from torch import Tensor
from torch.nn import Linear, ReLU, Sigmoid, Module, BCELoss, BCEWithLogitsLoss
from torch.optim import Adam
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from pandas import DataFrame
import xlsxwriter
import time

seed_value = 7
import os
os.environ['PYTHONHASHSEED']=str(seed_value)
import random
random.seed(seed_value)
import numpy as np
np.random.seed(seed_value)
import torch
torch.manual_seed(seed_value)

# %%
Training_Data = pd.ExcelFile("Labels.xlsx") #Training Data already pre-scaled to the IBIS Data set
data = Training_Data.parse(Training_Data.sheet_names[1])
label_data = Training_Data.parse(Training_Data.sheet_names[0])
data_features = data.loc[:, data.columns]
data_features = data_features.drop(['Case','Visit','MATCH','INDEX','ASD+','ASD-','Gender'], axis=1)
data_features = data_features.dropna()
data_features = data_features.drop(['Final Label'], axis=1)
labels = label_data.loc[:, label_data.columns]
labels = labels.drop(['CASE','MATCH','INDEX','ASD+','ASD-'], axis=1)
labels = labels.dropna()
print(data_features.shape)
print(labels.shape)
# Out:
# (325, 298)
# (325, 1)

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data_features)

scaled_data.shape
labels.shape

X_train, X_test, Y_train, Y_test = train_test_split(scaled_data, labels, test_size=0.10, random_state=seed_value)
sm = SMOTE(sampling_strategy = 'minority', random_state = seed_value, k_neighbors=2) 
X_train_smoted, Y_train_smoted = sm.fit_sample(X_train, Y_train) #Only smote the training set.

print(X_train_smoted.shape)
print(Y_train_smoted.shape)
# Out:
# (484, 298)
# (484, 1)

# %%
#Some hyperparameters
#D_in is input dimension; H is hidden dimension; D_out is output dimension. 
#Need to figure out how to get dropout 
D_in, H1, H2, D_out = 298, 110, 25, 1 
EPOCHS = 250 
BATCH_SIZE = 35 
LEARNING_RATE = 0.01

## train data
class trainData(Dataset):
    
    def __init__(self, X_data, y_data): #used to perform initializing operations such as reading data and preprocessing.
        self.X_data = X_data
        self.y_data = y_data
        
    def __getitem__(self, index): #returns data (input and output) in batches.
        return self.X_data[index], self.y_data[index]
        
    def __len__ (self): #returns the size of the input data.
        return len(self.X_data)

#A dataloader is then used on this dataset class to read the data in batches.
train_data = trainData(torch.FloatTensor(X_train_smoted), 
                       torch.FloatTensor(Y_train_smoted.values))
## test data    
class testData(Dataset):
    
    def __init__(self, X_data): ##used to perform initializing operations such as reading data and preprocessing.
        self.X_data = X_data
        
    def __getitem__(self, index): #returns data (input and output) in batches.
        return self.X_data[index]
        
    def __len__ (self): #returns the size of the input data.
        return len(self.X_data)
    
#A dataloader is then used on this dataset class to read the data in batches.
test_data = testData(torch.FloatTensor(X_test))

#Initialize DataLoaders
train_loader = DataLoader(dataset=train_data, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=33) #Batch size of the validation set. Need 1 at a time for how it was setup in the tutorial.

# %%
class binaryClassification(nn.Module):
    def __init__(self):
        super(binaryClassification, self).__init__()
        # Number of input features is 298.
        self.layer_1 = nn.Linear(D_in, H1) #298 -> 100
        self.layer_2 = nn.Linear(H1, H2) #100 -> 15
        self.layer_out = nn.Linear(H2, D_out) #15 -> 1
        
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.15)
        self.batchnorm1 = nn.BatchNorm1d(H1)
        self.batchnorm2 = nn.BatchNorm1d(H2)
        
    def forward(self, inputs):
        x = self.relu(self.layer_1(inputs)) #ReLU on the 298?
        x = self.batchnorm1(x) #Normalize the 100
        x = self.dropout(x) #Dropout 15%
        x = self.relu(self.layer_2(x)) #ReLU on the 100?
        x = self.batchnorm2(x) #Normalize the 15
        x = self.layer_out(x) #1
        
        return x
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
#Should use the CPU since I don't have a GPU.
# Out:
# cpu

# %%
#Model initialization and information on layers. The model's actual architecture can be viewed in the forward function above.
model = binaryClassification()
model.to(device)
print(model)
weights = torch.FloatTensor([5]) #Class weights?
criterion = nn.BCEWithLogitsLoss(pos_weight=weights)
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
# Out:
# binaryClassification(
#   (layer_1): Linear(in_features=298, out_features=110, bias=True)
#   (layer_2): Linear(in_features=110, out_features=25, bias=True)
#   (layer_out): Linear(in_features=25, out_features=1, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.15, inplace=False)
#   (batchnorm1): BatchNorm1d(110, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm2): BatchNorm1d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
#Function to define accuracy. Should look to see if there is a prebuilt that I can use from sci-kit learn or something.
def binary_acc(y_pred, y_test):
    y_pred_tag = torch.round(torch.sigmoid(y_pred))

    correct_results_sum = (y_pred_tag == y_test).sum().float()
    acc = correct_results_sum/y_test.shape[0]
    acc = torch.round(acc * 100)
    
    return acc

# %%
#model.train() tells PyTorch that you’re in training mode.
#Similarly, we’ll call model.eval() when we test our model. We’ll see that below.
'''If you’re using layers such as Dropout or BatchNorm which behave differently during training and evaluation, 
you need to tell PyTorch to act accordingly. While the default mode in PyTorch is the train, 
so, you don’t explicitly have to write that. But it’s good practice.'''
val_acc = []
train_acc = []
train_loss = []
val_loss = []

model.train() #Initial training mode
for e in range(1, EPOCHS+1):
    epoch_loss = 0
    epoch_acc = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        
        y_pred = model(X_batch)
        
        loss = criterion(y_pred, y_batch)
        acc = binary_acc(y_pred, y_batch)
        
        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        epoch_acc += acc.item()
    
    train_acc.append(epoch_acc/len(train_loader))
    train_loss.append(epoch_loss/len(train_loader))
    print(f'Training Epoch {e+0:03}: | Loss: {epoch_loss/len(train_loader):.5f} | Acc: {epoch_acc/len(train_loader):.3f}')
    #Validation metrics here
    model.eval()
    #print("Evaluation mode")
    y_pred_list = []
    test_loader = DataLoader(dataset=test_data, batch_size=33)
    with torch.no_grad():
        counter = 0
        for X_batch in test_loader:
            X_batch = X_batch.to(device)
            y_test_pred = model(X_batch)
            y_test_pred = torch.sigmoid(y_test_pred)
            y_pred_tag = torch.round(y_test_pred)
            y_pred_list.append(y_pred_tag.cpu().numpy())
            loss = criterion(y_test_pred,torch.FloatTensor(Y_test.values))
            val_loss.append(loss)
            counter+=1
            
    y_pred_list = []
    test_loader = DataLoader(dataset=test_data, batch_size=1)
    with torch.no_grad():
        for X_batch in test_loader:
            X_batch = X_batch.to(device)
            y_test_pred = model(X_batch)
            y_test_pred = torch.sigmoid(y_test_pred)
            y_pred_tag = torch.round(y_test_pred)
            y_pred_list.append(y_pred_tag.cpu().numpy())
            
    y_pred_list = [a.squeeze().tolist() for a in y_pred_list]
    y_loss_df = pd.DataFrame(y_pred_list)
    accuracy = accuracy_score(torch.FloatTensor(Y_test.values), y_pred_list)
    ppv = precision_score(Y_test, y_pred_list, average=None)
    recall = recall_score(Y_test, y_pred_list, average=None)
    print("Validation Accuracy | ",accuracy*100," PPV | ",ppv," Recall | ",recall)
    val_acc.append(accuracy*100)
    model.train()
    #print("Return to training mode")
    
    #Need to get validation loss.
# Out:
# Training Epoch 001: | Loss: 1.44225 | Acc: 77.071
# Validation Accuracy |  18.181818181818183  PPV |  [1.  0.1]  Recall |  [0.1 1. ]
# Training Epoch 002: | Loss: 0.52372 | Acc: 85.286
# Validation Accuracy |  33.33333333333333  PPV |  [1.   0.12]  Recall |  [0.26666667 1.        ]
# Training Epoch 003: | Loss: 0.36834 | Acc: 88.714
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 004: | Loss: 0.24844 | Acc: 91.500
# Validation Accuracy |  84.84848484848484  PPV |  [0.93103448 0.25      ]  Recall |  [0.9        0.33333333]
# Training Epoch 005: | Loss: 0.18867 | Acc: 94.071
# Validation Accuracy |  63.63636363636363  PPV |  [0.90909091 0.09090909]  Recall |  [0.66666667 0.33333333]
# Training Epoch 006: | Loss: 0.10413 | Acc: 98.071
# Validation Accuracy |  87.87878787878788  PPV |  [0.90625 0.     ]  Recall |  [0.96666667 0.        ]
# Training Epoch 007: | Loss: 0.15499 | Acc: 95.857
# Validation Accuracy |  75.75757575757575  PPV |  [0.92307692 0.14285714]  Recall |  [0.8        0.33333333]
# Training Epoch 008: | Loss: 0.10446 | Acc: 97.500
# Validation Accuracy |  75.75757575757575  PPV |  [0.92307692 0.14285714]  Recall |  [0.8        0.33333333]
# Training Epoch 009: | Loss: 0.10374 | Acc: 97.571
# Validation Accuracy |  69.6969696969697  PPV |  [0.95454545 0.18181818]  Recall |  [0.7        0.66666667]
# Training Epoch 010: | Loss: 0.06850 | Acc: 98.286
# Validation Accuracy |  54.54545454545454  PPV |  [0.94117647 0.125     ]  Recall |  [0.53333333 0.66666667]
# Training Epoch 011: | Loss: 0.08811 | Acc: 97.500
# Validation Accuracy |  87.87878787878788  PPV |  [0.90625 0.     ]  Recall |  [0.96666667 0.        ]
# Training Epoch 012: | Loss: 0.04767 | Acc: 98.929
# Validation Accuracy |  30.303030303030305  PPV |  [1.         0.11538462]  Recall |  [0.23333333 1.        ]
# Training Epoch 013: | Loss: 0.07401 | Acc: 99.357
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 014: | Loss: 0.18796 | Acc: 94.786
# Validation Accuracy |  57.57575757575758  PPV |  [0.9        0.07692308]  Recall |  [0.6        0.33333333]
# Training Epoch 015: | Loss: 0.23146 | Acc: 94.929
# Validation Accuracy |  30.303030303030305  PPV |  [0.88888889 0.08333333]  Recall |  [0.26666667 0.66666667]
# Training Epoch 016: | Loss: 0.11838 | Acc: 97.429
# Validation Accuracy |  9.090909090909092  PPV |  [0.         0.09090909]  Recall |  [0. 1.]
# C:\Users\mattbeze\Anaconda3\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Training Epoch 017: | Loss: 0.11390 | Acc: 96.786
# Validation Accuracy |  24.242424242424242  PPV |  [0.77777778 0.04166667]  Recall |  [0.23333333 0.33333333]
# Training Epoch 018: | Loss: 0.13211 | Acc: 95.786
# Validation Accuracy |  42.42424242424242  PPV |  [0.86666667 0.05555556]  Recall |  [0.43333333 0.33333333]
# Training Epoch 019: | Loss: 0.09427 | Acc: 97.643
# Validation Accuracy |  21.21212121212121  PPV |  [1.         0.10344828]  Recall |  [0.13333333 1.        ]
# Training Epoch 020: | Loss: 0.19052 | Acc: 96.929
# Validation Accuracy |  18.181818181818183  PPV |  [1.  0.1]  Recall |  [0.1 1. ]
# Training Epoch 021: | Loss: 0.17784 | Acc: 94.500
# Validation Accuracy |  18.181818181818183  PPV |  [0.8        0.07142857]  Recall |  [0.13333333 0.66666667]
# Training Epoch 022: | Loss: 0.10036 | Acc: 96.857
# Validation Accuracy |  54.54545454545454  PPV |  [0.85714286 0.        ]  Recall |  [0.6 0. ]
# Training Epoch 023: | Loss: 0.12411 | Acc: 98.286
# Validation Accuracy |  54.54545454545454  PPV |  [0.89473684 0.07142857]  Recall |  [0.56666667 0.33333333]
# Training Epoch 024: | Loss: 0.07936 | Acc: 97.643
# Validation Accuracy |  84.84848484848484  PPV |  [0.90322581 0.        ]  Recall |  [0.93333333 0.        ]
# Training Epoch 025: | Loss: 0.09435 | Acc: 97.071
# Validation Accuracy |  42.42424242424242  PPV |  [0.86666667 0.05555556]  Recall |  [0.43333333 0.33333333]
# Training Epoch 026: | Loss: 0.05139 | Acc: 98.929
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 027: | Loss: 0.03391 | Acc: 99.357
# Validation Accuracy |  81.81818181818183  PPV |  [0.9 0. ]  Recall |  [0.9 0. ]
# Training Epoch 028: | Loss: 0.01600 | Acc: 99.786
# Validation Accuracy |  84.84848484848484  PPV |  [0.90322581 0.        ]  Recall |  [0.93333333 0.        ]
# Training Epoch 029: | Loss: 0.02212 | Acc: 99.571
# Validation Accuracy |  81.81818181818183  PPV |  [0.92857143 0.2       ]  Recall |  [0.86666667 0.33333333]
# Training Epoch 030: | Loss: 0.01093 | Acc: 99.786
# Validation Accuracy |  84.84848484848484  PPV |  [0.93103448 0.25      ]  Recall |  [0.9        0.33333333]
# Training Epoch 031: | Loss: 0.00946 | Acc: 100.000
# Validation Accuracy |  81.81818181818183  PPV |  [0.9 0. ]  Recall |  [0.9 0. ]
# Training Epoch 032: | Loss: 0.06255 | Acc: 98.357
# Validation Accuracy |  42.42424242424242  PPV |  [0.86666667 0.05555556]  Recall |  [0.43333333 0.33333333]
# Training Epoch 033: | Loss: 0.05755 | Acc: 98.071
# Validation Accuracy |  66.66666666666666  PPV |  [0.88 0.  ]  Recall |  [0.73333333 0.        ]
# Training Epoch 034: | Loss: 0.03724 | Acc: 99.357
# Validation Accuracy |  69.6969696969697  PPV |  [0.91666667 0.11111111]  Recall |  [0.73333333 0.33333333]
# Training Epoch 035: | Loss: 0.01327 | Acc: 100.000
# Validation Accuracy |  66.66666666666666  PPV |  [0.91304348 0.1       ]  Recall |  [0.7        0.33333333]
# Training Epoch 036: | Loss: 0.01275 | Acc: 99.571
# Validation Accuracy |  69.6969696969697  PPV |  [0.91666667 0.11111111]  Recall |  [0.73333333 0.33333333]
# Training Epoch 037: | Loss: 0.00885 | Acc: 100.000
# Validation Accuracy |  84.84848484848484  PPV |  [0.93103448 0.25      ]  Recall |  [0.9        0.33333333]
# Training Epoch 038: | Loss: 0.00738 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 039: | Loss: 0.00680 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 040: | Loss: 0.00807 | Acc: 99.786
# Validation Accuracy |  81.81818181818183  PPV |  [0.92857143 0.2       ]  Recall |  [0.86666667 0.33333333]
# Training Epoch 041: | Loss: 0.00372 | Acc: 100.000
# Validation Accuracy |  75.75757575757575  PPV |  [0.92307692 0.14285714]  Recall |  [0.8        0.33333333]
# Training Epoch 042: | Loss: 0.00779 | Acc: 100.000
# Validation Accuracy |  69.6969696969697  PPV |  [0.91666667 0.11111111]  Recall |  [0.73333333 0.33333333]
# Training Epoch 043: | Loss: 0.00284 | Acc: 100.000
# Validation Accuracy |  75.75757575757575  PPV |  [0.92307692 0.14285714]  Recall |  [0.8        0.33333333]
# Training Epoch 044: | Loss: 0.00240 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 045: | Loss: 0.01751 | Acc: 99.571
# Validation Accuracy |  72.72727272727273  PPV |  [0.92  0.125]  Recall |  [0.76666667 0.33333333]
# Training Epoch 046: | Loss: 0.01305 | Acc: 99.357
# Validation Accuracy |  72.72727272727273  PPV |  [0.88888889 0.        ]  Recall |  [0.8 0. ]
# Training Epoch 047: | Loss: 0.01034 | Acc: 99.786
# Validation Accuracy |  81.81818181818183  PPV |  [0.9 0. ]  Recall |  [0.9 0. ]
# Training Epoch 048: | Loss: 0.00706 | Acc: 100.000
# Validation Accuracy |  84.84848484848484  PPV |  [0.93103448 0.25      ]  Recall |  [0.9        0.33333333]
# Training Epoch 049: | Loss: 0.00465 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 050: | Loss: 0.00319 | Acc: 100.000
# Validation Accuracy |  72.72727272727273  PPV |  [0.88888889 0.        ]  Recall |  [0.8 0. ]
# Training Epoch 051: | Loss: 0.04135 | Acc: 98.929
# Validation Accuracy |  33.33333333333333  PPV |  [0.83333333 0.04761905]  Recall |  [0.33333333 0.33333333]
# Training Epoch 052: | Loss: 0.05298 | Acc: 99.143
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 053: | Loss: 0.07511 | Acc: 97.500
# Validation Accuracy |  45.45454545454545  PPV |  [0.875      0.05882353]  Recall |  [0.46666667 0.33333333]
# Training Epoch 054: | Loss: 0.05999 | Acc: 99.143
# Validation Accuracy |  69.6969696969697  PPV |  [0.88461538 0.        ]  Recall |  [0.76666667 0.        ]
# Training Epoch 055: | Loss: 0.04669 | Acc: 98.714
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 056: | Loss: 0.11005 | Acc: 97.857
# Validation Accuracy |  84.84848484848484  PPV |  [0.93103448 0.25      ]  Recall |  [0.9        0.33333333]
# Training Epoch 057: | Loss: 0.03999 | Acc: 98.500
# Validation Accuracy |  81.81818181818183  PPV |  [0.9 0. ]  Recall |  [0.9 0. ]
# Training Epoch 058: | Loss: 0.05772 | Acc: 98.143
# Validation Accuracy |  72.72727272727273  PPV |  [0.92  0.125]  Recall |  [0.76666667 0.33333333]
# Training Epoch 059: | Loss: 0.04190 | Acc: 98.714
# Validation Accuracy |  63.63636363636363  PPV |  [0.875 0.   ]  Recall |  [0.7 0. ]
# Training Epoch 060: | Loss: 0.08915 | Acc: 97.429
# Validation Accuracy |  54.54545454545454  PPV |  [0.89473684 0.07142857]  Recall |  [0.56666667 0.33333333]
# Training Epoch 061: | Loss: 0.11600 | Acc: 98.714
# Validation Accuracy |  87.87878787878788  PPV |  [0.93333333 0.33333333]  Recall |  [0.93333333 0.33333333]
# Training Epoch 062: | Loss: 0.19154 | Acc: 96.286
# Validation Accuracy |  21.21212121212121  PPV |  [0.83333333 0.07407407]  Recall |  [0.16666667 0.66666667]
# Training Epoch 063: | Loss: 0.25155 | Acc: 93.929
# Validation Accuracy |  66.66666666666666  PPV |  [0.88 0.  ]  Recall |  [0.73333333 0.        ]
# Training Epoch 064: | Loss: 0.21496 | Acc: 94.571
# Validation Accuracy |  54.54545454545454  PPV |  [0.85714286 0.        ]  Recall |  [0.6 0. ]
# Training Epoch 065: | Loss: 0.13328 | Acc: 96.643
# Validation Accuracy |  87.87878787878788  PPV |  [0.90625 0.     ]  Recall |  [0.96666667 0.        ]
# Training Epoch 066: | Loss: 0.06154 | Acc: 98.500
# Validation Accuracy |  72.72727272727273  PPV |  [0.88888889 0.        ]  Recall |  [0.8 0. ]
# Training Epoch 067: | Loss: 0.04490 | Acc: 98.286
# Validation Accuracy |  72.72727272727273  PPV |  [0.88888889 0.        ]  Recall |  [0.8 0. ]
# Training Epoch 068: | Loss: 0.05214 | Acc: 98.429
# Validation Accuracy |  69.6969696969697  PPV |  [0.91666667 0.11111111]  Recall |  [0.73333333 0.33333333]
# Training Epoch 069: | Loss: 0.02060 | Acc: 99.786
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 070: | Loss: 0.03476 | Acc: 98.929
# Validation Accuracy |  75.75757575757575  PPV |  [0.92307692 0.14285714]  Recall |  [0.8        0.33333333]
# Training Epoch 071: | Loss: 0.02755 | Acc: 99.357
# Validation Accuracy |  69.6969696969697  PPV |  [0.88461538 0.        ]  Recall |  [0.76666667 0.        ]
# Training Epoch 072: | Loss: 0.02459 | Acc: 99.357
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 073: | Loss: 0.02324 | Acc: 99.786
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 074: | Loss: 0.02802 | Acc: 99.571
# Validation Accuracy |  63.63636363636363  PPV |  [0.90909091 0.09090909]  Recall |  [0.66666667 0.33333333]
# Training Epoch 075: | Loss: 0.02078 | Acc: 99.143
# Validation Accuracy |  63.63636363636363  PPV |  [0.875 0.   ]  Recall |  [0.7 0. ]
# Training Epoch 076: | Loss: 0.00859 | Acc: 100.000
# Validation Accuracy |  72.72727272727273  PPV |  [0.88888889 0.        ]  Recall |  [0.8 0. ]
# Training Epoch 077: | Loss: 0.03226 | Acc: 99.143
# Validation Accuracy |  72.72727272727273  PPV |  [0.88888889 0.        ]  Recall |  [0.8 0. ]
# Training Epoch 078: | Loss: 0.01909 | Acc: 99.571
# Validation Accuracy |  84.84848484848484  PPV |  [0.90322581 0.        ]  Recall |  [0.93333333 0.        ]
# Training Epoch 079: | Loss: 0.03500 | Acc: 99.357
# Validation Accuracy |  75.75757575757575  PPV |  [0.92307692 0.14285714]  Recall |  [0.8        0.33333333]
# Training Epoch 080: | Loss: 0.02345 | Acc: 99.571
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 081: | Loss: 0.04350 | Acc: 99.000
# Validation Accuracy |  84.84848484848484  PPV |  [0.90322581 0.        ]  Recall |  [0.93333333 0.        ]
# Training Epoch 082: | Loss: 0.01421 | Acc: 99.571
# Validation Accuracy |  69.6969696969697  PPV |  [0.88461538 0.        ]  Recall |  [0.76666667 0.        ]
# Training Epoch 083: | Loss: 0.05118 | Acc: 99.143
# Validation Accuracy |  69.6969696969697  PPV |  [0.88461538 0.        ]  Recall |  [0.76666667 0.        ]
# Training Epoch 084: | Loss: 0.03162 | Acc: 99.143
# Validation Accuracy |  48.484848484848484  PPV |  [0.88235294 0.0625    ]  Recall |  [0.5        0.33333333]
# Training Epoch 085: | Loss: 0.03409 | Acc: 99.357
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 086: | Loss: 0.01337 | Acc: 99.571
# Validation Accuracy |  84.84848484848484  PPV |  [0.90322581 0.        ]  Recall |  [0.93333333 0.        ]
# Training Epoch 087: | Loss: 0.00868 | Acc: 99.786
# Validation Accuracy |  81.81818181818183  PPV |  [0.9 0. ]  Recall |  [0.9 0. ]
# Training Epoch 088: | Loss: 0.00759 | Acc: 100.000
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 089: | Loss: 0.01506 | Acc: 99.786
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 090: | Loss: 0.01583 | Acc: 99.357
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 091: | Loss: 0.01039 | Acc: 99.571
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 092: | Loss: 0.00353 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 093: | Loss: 0.01268 | Acc: 99.786
# Validation Accuracy |  84.84848484848484  PPV |  [0.90322581 0.        ]  Recall |  [0.93333333 0.        ]
# Training Epoch 094: | Loss: 0.00197 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 095: | Loss: 0.02324 | Acc: 98.429
# Validation Accuracy |  72.72727272727273  PPV |  [0.88888889 0.        ]  Recall |  [0.8 0. ]
# Training Epoch 096: | Loss: 0.00773 | Acc: 99.786
# Validation Accuracy |  72.72727272727273  PPV |  [0.88888889 0.        ]  Recall |  [0.8 0. ]
# Training Epoch 097: | Loss: 0.00306 | Acc: 100.000
# Validation Accuracy |  72.72727272727273  PPV |  [0.88888889 0.        ]  Recall |  [0.8 0. ]
# Training Epoch 098: | Loss: 0.00535 | Acc: 100.000
# Validation Accuracy |  72.72727272727273  PPV |  [0.88888889 0.        ]  Recall |  [0.8 0. ]
# Training Epoch 099: | Loss: 0.00829 | Acc: 100.000
# Validation Accuracy |  75.75757575757575  PPV |  [0.92307692 0.14285714]  Recall |  [0.8        0.33333333]
# Training Epoch 100: | Loss: 0.00538 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 101: | Loss: 0.01148 | Acc: 99.571
# Validation Accuracy |  75.75757575757575  PPV |  [0.92307692 0.14285714]  Recall |  [0.8        0.33333333]
# Training Epoch 102: | Loss: 0.03538 | Acc: 99.000
# Validation Accuracy |  84.84848484848484  PPV |  [0.90322581 0.        ]  Recall |  [0.93333333 0.        ]
# Training Epoch 103: | Loss: 0.00210 | Acc: 100.000
# Validation Accuracy |  84.84848484848484  PPV |  [0.90322581 0.        ]  Recall |  [0.93333333 0.        ]
# Training Epoch 104: | Loss: 0.00231 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 105: | Loss: 0.00726 | Acc: 99.786
# Validation Accuracy |  72.72727272727273  PPV |  [0.88888889 0.        ]  Recall |  [0.8 0. ]
# Training Epoch 106: | Loss: 0.00542 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 107: | Loss: 0.00186 | Acc: 100.000
# Validation Accuracy |  81.81818181818183  PPV |  [0.9 0. ]  Recall |  [0.9 0. ]
# Training Epoch 108: | Loss: 0.00327 | Acc: 100.000
# Validation Accuracy |  81.81818181818183  PPV |  [0.9 0. ]  Recall |  [0.9 0. ]
# Training Epoch 109: | Loss: 0.00642 | Acc: 99.786
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 110: | Loss: 0.04520 | Acc: 99.571
# Validation Accuracy |  54.54545454545454  PPV |  [0.85714286 0.        ]  Recall |  [0.6 0. ]
# Training Epoch 111: | Loss: 0.01548 | Acc: 99.357
# Validation Accuracy |  72.72727272727273  PPV |  [0.88888889 0.        ]  Recall |  [0.8 0. ]
# Training Epoch 112: | Loss: 0.01638 | Acc: 99.357
# Validation Accuracy |  81.81818181818183  PPV |  [0.9 0. ]  Recall |  [0.9 0. ]
# Training Epoch 113: | Loss: 0.00997 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 114: | Loss: 0.05139 | Acc: 99.357
# Validation Accuracy |  81.81818181818183  PPV |  [0.9 0. ]  Recall |  [0.9 0. ]
# Training Epoch 115: | Loss: 0.02908 | Acc: 98.929
# Validation Accuracy |  54.54545454545454  PPV |  [0.85714286 0.        ]  Recall |  [0.6 0. ]
# Training Epoch 116: | Loss: 0.06914 | Acc: 98.714
# Validation Accuracy |  54.54545454545454  PPV |  [0.94117647 0.125     ]  Recall |  [0.53333333 0.66666667]
# Training Epoch 117: | Loss: 0.10455 | Acc: 97.857
# Validation Accuracy |  81.81818181818183  PPV |  [0.92857143 0.2       ]  Recall |  [0.86666667 0.33333333]
# Training Epoch 118: | Loss: 0.03899 | Acc: 98.714
# Validation Accuracy |  90.9090909090909  PPV |  [0.93548387 0.5       ]  Recall |  [0.96666667 0.33333333]
# Training Epoch 119: | Loss: 0.03212 | Acc: 99.214
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 120: | Loss: 0.02851 | Acc: 99.571
# Validation Accuracy |  63.63636363636363  PPV |  [0.875 0.   ]  Recall |  [0.7 0. ]
# Training Epoch 121: | Loss: 0.03824 | Acc: 98.714
# Validation Accuracy |  72.72727272727273  PPV |  [0.88888889 0.        ]  Recall |  [0.8 0. ]
# Training Epoch 122: | Loss: 0.01121 | Acc: 99.571
# Validation Accuracy |  69.6969696969697  PPV |  [0.88461538 0.        ]  Recall |  [0.76666667 0.        ]
# Training Epoch 123: | Loss: 0.02985 | Acc: 99.357
# Validation Accuracy |  84.84848484848484  PPV |  [0.90322581 0.        ]  Recall |  [0.93333333 0.        ]
# Training Epoch 124: | Loss: 0.03653 | Acc: 98.929
# Validation Accuracy |  54.54545454545454  PPV |  [0.89473684 0.07142857]  Recall |  [0.56666667 0.33333333]
# Training Epoch 125: | Loss: 0.04589 | Acc: 98.500
# Validation Accuracy |  57.57575757575758  PPV |  [0.94444444 0.13333333]  Recall |  [0.56666667 0.66666667]
# Training Epoch 126: | Loss: 0.02453 | Acc: 99.143
# Validation Accuracy |  63.63636363636363  PPV |  [0.875 0.   ]  Recall |  [0.7 0. ]
# Training Epoch 127: | Loss: 0.04090 | Acc: 98.929
# Validation Accuracy |  84.84848484848484  PPV |  [0.90322581 0.        ]  Recall |  [0.93333333 0.        ]
# Training Epoch 128: | Loss: 0.07007 | Acc: 98.571
# Validation Accuracy |  39.39393939393939  PPV |  [1.         0.13043478]  Recall |  [0.33333333 1.        ]
# Training Epoch 129: | Loss: 0.11804 | Acc: 97.143
# Validation Accuracy |  84.84848484848484  PPV |  [0.90322581 0.        ]  Recall |  [0.93333333 0.        ]
# Training Epoch 130: | Loss: 0.03984 | Acc: 98.929
# Validation Accuracy |  66.66666666666666  PPV |  [0.88 0.  ]  Recall |  [0.73333333 0.        ]
# Training Epoch 131: | Loss: 0.01770 | Acc: 99.143
# Validation Accuracy |  72.72727272727273  PPV |  [0.92  0.125]  Recall |  [0.76666667 0.33333333]
# Training Epoch 132: | Loss: 0.01467 | Acc: 99.786
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 133: | Loss: 0.02068 | Acc: 99.357
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 134: | Loss: 0.01660 | Acc: 99.571
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 135: | Loss: 0.14385 | Acc: 98.714
# Validation Accuracy |  69.6969696969697  PPV |  [0.95454545 0.18181818]  Recall |  [0.7        0.66666667]
# Training Epoch 136: | Loss: 0.06667 | Acc: 98.357
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 137: | Loss: 0.02374 | Acc: 99.357
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 138: | Loss: 0.04714 | Acc: 99.143
# Validation Accuracy |  54.54545454545454  PPV |  [0.85714286 0.        ]  Recall |  [0.6 0. ]
# Training Epoch 139: | Loss: 0.01245 | Acc: 99.786
# Validation Accuracy |  63.63636363636363  PPV |  [0.875 0.   ]  Recall |  [0.7 0. ]
# Training Epoch 140: | Loss: 0.05091 | Acc: 98.714
# Validation Accuracy |  75.75757575757575  PPV |  [0.92307692 0.14285714]  Recall |  [0.8        0.33333333]
# Training Epoch 141: | Loss: 0.02498 | Acc: 99.143
# Validation Accuracy |  72.72727272727273  PPV |  [0.92  0.125]  Recall |  [0.76666667 0.33333333]
# Training Epoch 142: | Loss: 0.01019 | Acc: 99.786
# Validation Accuracy |  69.6969696969697  PPV |  [0.91666667 0.11111111]  Recall |  [0.73333333 0.33333333]
# Training Epoch 143: | Loss: 0.01828 | Acc: 99.571
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 144: | Loss: 0.00114 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 145: | Loss: 0.01110 | Acc: 99.571
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 146: | Loss: 0.02794 | Acc: 99.571
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 147: | Loss: 0.01627 | Acc: 99.786
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 148: | Loss: 0.00695 | Acc: 99.786
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 149: | Loss: 0.02610 | Acc: 99.143
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 150: | Loss: 0.00771 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 151: | Loss: 0.00483 | Acc: 99.786
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 152: | Loss: 0.00750 | Acc: 99.786
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 153: | Loss: 0.00930 | Acc: 99.786
# Validation Accuracy |  63.63636363636363  PPV |  [0.90909091 0.09090909]  Recall |  [0.66666667 0.33333333]
# Training Epoch 154: | Loss: 0.02571 | Acc: 99.357
# Validation Accuracy |  90.9090909090909  PPV |  [0.90909091 0.        ]  Recall |  [1. 0.]
# Training Epoch 155: | Loss: 0.07941 | Acc: 98.929
# Validation Accuracy |  60.60606060606061  PPV |  [0.86956522 0.        ]  Recall |  [0.66666667 0.        ]
# Training Epoch 156: | Loss: 0.00535 | Acc: 99.786
# C:\Users\mattbeze\Anaconda3\envs\pytorch\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Validation Accuracy |  30.303030303030305  PPV |  [0.81818182 0.04545455]  Recall |  [0.3        0.33333333]
# Training Epoch 157: | Loss: 0.03286 | Acc: 98.929
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 158: | Loss: 0.03445 | Acc: 98.929
# Validation Accuracy |  72.72727272727273  PPV |  [0.92  0.125]  Recall |  [0.76666667 0.33333333]
# Training Epoch 159: | Loss: 0.01008 | Acc: 99.786
# Validation Accuracy |  66.66666666666666  PPV |  [0.91304348 0.1       ]  Recall |  [0.7        0.33333333]
# Training Epoch 160: | Loss: 0.01355 | Acc: 99.786
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 161: | Loss: 0.00283 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 162: | Loss: 0.00713 | Acc: 99.786
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 163: | Loss: 0.00161 | Acc: 100.000
# Validation Accuracy |  81.81818181818183  PPV |  [0.92857143 0.2       ]  Recall |  [0.86666667 0.33333333]
# Training Epoch 164: | Loss: 0.00154 | Acc: 100.000
# Validation Accuracy |  81.81818181818183  PPV |  [0.92857143 0.2       ]  Recall |  [0.86666667 0.33333333]
# Training Epoch 165: | Loss: 0.00609 | Acc: 100.000
# Validation Accuracy |  66.66666666666666  PPV |  [0.91304348 0.1       ]  Recall |  [0.7        0.33333333]
# Training Epoch 166: | Loss: 0.00294 | Acc: 99.786
# Validation Accuracy |  72.72727272727273  PPV |  [0.92  0.125]  Recall |  [0.76666667 0.33333333]
# Training Epoch 167: | Loss: 0.00539 | Acc: 99.786
# Validation Accuracy |  75.75757575757575  PPV |  [0.92307692 0.14285714]  Recall |  [0.8        0.33333333]
# Training Epoch 168: | Loss: 0.00476 | Acc: 100.000
# Validation Accuracy |  81.81818181818183  PPV |  [0.92857143 0.2       ]  Recall |  [0.86666667 0.33333333]
# Training Epoch 169: | Loss: 0.00200 | Acc: 100.000
# Validation Accuracy |  81.81818181818183  PPV |  [0.92857143 0.2       ]  Recall |  [0.86666667 0.33333333]
# Training Epoch 170: | Loss: 0.00062 | Acc: 100.000
# Validation Accuracy |  81.81818181818183  PPV |  [0.92857143 0.2       ]  Recall |  [0.86666667 0.33333333]
# Training Epoch 171: | Loss: 0.03369 | Acc: 99.357
# Validation Accuracy |  66.66666666666666  PPV |  [0.91304348 0.1       ]  Recall |  [0.7        0.33333333]
# Training Epoch 172: | Loss: 0.01293 | Acc: 99.571
# Validation Accuracy |  75.75757575757575  PPV |  [0.92307692 0.14285714]  Recall |  [0.8        0.33333333]
# Training Epoch 173: | Loss: 0.00537 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 174: | Loss: 0.00185 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 175: | Loss: 0.00276 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 176: | Loss: 0.03516 | Acc: 99.357
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 177: | Loss: 0.00847 | Acc: 99.571
# Validation Accuracy |  54.54545454545454  PPV |  [0.85714286 0.        ]  Recall |  [0.6 0. ]
# Training Epoch 178: | Loss: 0.02318 | Acc: 99.143
# Validation Accuracy |  66.66666666666666  PPV |  [0.88 0.  ]  Recall |  [0.73333333 0.        ]
# Training Epoch 179: | Loss: 0.02124 | Acc: 99.357
# Validation Accuracy |  75.75757575757575  PPV |  [0.92307692 0.14285714]  Recall |  [0.8        0.33333333]
# Training Epoch 180: | Loss: 0.00357 | Acc: 100.000
# Validation Accuracy |  75.75757575757575  PPV |  [0.92307692 0.14285714]  Recall |  [0.8        0.33333333]
# Training Epoch 181: | Loss: 0.01913 | Acc: 99.571
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 182: | Loss: 0.01876 | Acc: 99.571
# Validation Accuracy |  69.6969696969697  PPV |  [0.88461538 0.        ]  Recall |  [0.76666667 0.        ]
# Training Epoch 183: | Loss: 0.00809 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 184: | Loss: 0.01134 | Acc: 99.786
# Validation Accuracy |  45.45454545454545  PPV |  [0.875      0.05882353]  Recall |  [0.46666667 0.33333333]
# Training Epoch 185: | Loss: 0.00680 | Acc: 99.786
# Validation Accuracy |  54.54545454545454  PPV |  [0.89473684 0.07142857]  Recall |  [0.56666667 0.33333333]
# Training Epoch 186: | Loss: 0.01258 | Acc: 99.357
# Validation Accuracy |  81.81818181818183  PPV |  [0.92857143 0.2       ]  Recall |  [0.86666667 0.33333333]
# Training Epoch 187: | Loss: 0.00313 | Acc: 100.000
# Validation Accuracy |  81.81818181818183  PPV |  [0.92857143 0.2       ]  Recall |  [0.86666667 0.33333333]
# Training Epoch 188: | Loss: 0.01867 | Acc: 99.571
# Validation Accuracy |  87.87878787878788  PPV |  [0.90625 0.     ]  Recall |  [0.96666667 0.        ]
# Training Epoch 189: | Loss: 0.01069 | Acc: 99.786
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 190: | Loss: 0.01198 | Acc: 99.571
# Validation Accuracy |  69.6969696969697  PPV |  [0.88461538 0.        ]  Recall |  [0.76666667 0.        ]
# Training Epoch 191: | Loss: 0.00619 | Acc: 99.786
# Validation Accuracy |  69.6969696969697  PPV |  [0.88461538 0.        ]  Recall |  [0.76666667 0.        ]
# Training Epoch 192: | Loss: 0.00524 | Acc: 100.000
# Validation Accuracy |  72.72727272727273  PPV |  [0.88888889 0.        ]  Recall |  [0.8 0. ]
# Training Epoch 193: | Loss: 0.00147 | Acc: 100.000
# Validation Accuracy |  75.75757575757575  PPV |  [0.92307692 0.14285714]  Recall |  [0.8        0.33333333]
# Training Epoch 194: | Loss: 0.00212 | Acc: 100.000
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 195: | Loss: 0.00357 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 196: | Loss: 0.01862 | Acc: 99.571
# Validation Accuracy |  75.75757575757575  PPV |  [0.92307692 0.14285714]  Recall |  [0.8        0.33333333]
# Training Epoch 197: | Loss: 0.00471 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 198: | Loss: 0.00919 | Acc: 99.786
# Validation Accuracy |  72.72727272727273  PPV |  [0.92  0.125]  Recall |  [0.76666667 0.33333333]
# Training Epoch 199: | Loss: 0.00665 | Acc: 99.786
# Validation Accuracy |  72.72727272727273  PPV |  [0.92  0.125]  Recall |  [0.76666667 0.33333333]
# Training Epoch 200: | Loss: 0.01054 | Acc: 99.786
# Validation Accuracy |  72.72727272727273  PPV |  [0.92  0.125]  Recall |  [0.76666667 0.33333333]
# Training Epoch 201: | Loss: 0.00259 | Acc: 100.000
# Validation Accuracy |  72.72727272727273  PPV |  [0.92  0.125]  Recall |  [0.76666667 0.33333333]
# Training Epoch 202: | Loss: 0.00054 | Acc: 100.000
# Validation Accuracy |  72.72727272727273  PPV |  [0.92  0.125]  Recall |  [0.76666667 0.33333333]
# Training Epoch 203: | Loss: 0.01549 | Acc: 99.786
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 204: | Loss: 0.00441 | Acc: 99.786
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 205: | Loss: 0.00402 | Acc: 99.786
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 206: | Loss: 0.00063 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 207: | Loss: 0.00205 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 208: | Loss: 0.00172 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 209: | Loss: 0.00286 | Acc: 99.786
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 210: | Loss: 0.03581 | Acc: 99.143
# Validation Accuracy |  69.6969696969697  PPV |  [0.91666667 0.11111111]  Recall |  [0.73333333 0.33333333]
# Training Epoch 211: | Loss: 0.01675 | Acc: 99.786
# Validation Accuracy |  81.81818181818183  PPV |  [0.9 0. ]  Recall |  [0.9 0. ]
# Training Epoch 212: | Loss: 0.01623 | Acc: 99.786
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 213: | Loss: 0.01314 | Acc: 99.571
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 214: | Loss: 0.01714 | Acc: 99.357
# Validation Accuracy |  75.75757575757575  PPV |  [0.92307692 0.14285714]  Recall |  [0.8        0.33333333]
# Training Epoch 215: | Loss: 0.04775 | Acc: 99.357
# Validation Accuracy |  60.60606060606061  PPV |  [0.9047619  0.08333333]  Recall |  [0.63333333 0.33333333]
# Training Epoch 216: | Loss: 0.02271 | Acc: 99.357
# Validation Accuracy |  66.66666666666666  PPV |  [0.88 0.  ]  Recall |  [0.73333333 0.        ]
# Training Epoch 217: | Loss: 0.01573 | Acc: 99.357
# Validation Accuracy |  78.78787878787878  PPV |  [0.89655172 0.        ]  Recall |  [0.86666667 0.        ]
# Training Epoch 218: | Loss: 0.02272 | Acc: 99.786
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 219: | Loss: 0.04387 | Acc: 99.571
# Validation Accuracy |  57.57575757575758  PPV |  [0.9        0.07692308]  Recall |  [0.6        0.33333333]
# Training Epoch 220: | Loss: 0.05131 | Acc: 99.143
# Validation Accuracy |  63.63636363636363  PPV |  [0.90909091 0.09090909]  Recall |  [0.66666667 0.33333333]
# Training Epoch 221: | Loss: 0.03412 | Acc: 98.929
# Validation Accuracy |  33.33333333333333  PPV |  [0.83333333 0.04761905]  Recall |  [0.33333333 0.33333333]
# Training Epoch 222: | Loss: 0.06675 | Acc: 97.714
# Validation Accuracy |  87.87878787878788  PPV |  [0.90625 0.     ]  Recall |  [0.96666667 0.        ]
# Training Epoch 223: | Loss: 0.02624 | Acc: 99.786
# Validation Accuracy |  60.60606060606061  PPV |  [0.9047619  0.08333333]  Recall |  [0.63333333 0.33333333]
# Training Epoch 224: | Loss: 0.00360 | Acc: 100.000
# Validation Accuracy |  54.54545454545454  PPV |  [0.89473684 0.07142857]  Recall |  [0.56666667 0.33333333]
# Training Epoch 225: | Loss: 0.03451 | Acc: 99.143
# Validation Accuracy |  75.75757575757575  PPV |  [0.92307692 0.14285714]  Recall |  [0.8        0.33333333]
# Training Epoch 226: | Loss: 0.01272 | Acc: 99.571
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 227: | Loss: 0.00999 | Acc: 99.786
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 228: | Loss: 0.00318 | Acc: 100.000
# Validation Accuracy |  69.6969696969697  PPV |  [0.88461538 0.        ]  Recall |  [0.76666667 0.        ]
# Training Epoch 229: | Loss: 0.01105 | Acc: 99.786
# Validation Accuracy |  66.66666666666666  PPV |  [0.88 0.  ]  Recall |  [0.73333333 0.        ]
# Training Epoch 230: | Loss: 0.00825 | Acc: 99.786
# Validation Accuracy |  63.63636363636363  PPV |  [0.90909091 0.09090909]  Recall |  [0.66666667 0.33333333]
# Training Epoch 231: | Loss: 0.00568 | Acc: 100.000
# Validation Accuracy |  63.63636363636363  PPV |  [0.90909091 0.09090909]  Recall |  [0.66666667 0.33333333]
# Training Epoch 232: | Loss: 0.00149 | Acc: 100.000
# Validation Accuracy |  72.72727272727273  PPV |  [0.92  0.125]  Recall |  [0.76666667 0.33333333]
# Training Epoch 233: | Loss: 0.01475 | Acc: 99.786
# Validation Accuracy |  75.75757575757575  PPV |  [0.92307692 0.14285714]  Recall |  [0.8        0.33333333]
# Training Epoch 234: | Loss: 0.01843 | Acc: 99.143
# Validation Accuracy |  81.81818181818183  PPV |  [0.92857143 0.2       ]  Recall |  [0.86666667 0.33333333]
# Training Epoch 235: | Loss: 0.00199 | Acc: 100.000
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 236: | Loss: 0.05353 | Acc: 99.143
# Validation Accuracy |  66.66666666666666  PPV |  [0.88 0.  ]  Recall |  [0.73333333 0.        ]
# Training Epoch 237: | Loss: 0.01776 | Acc: 99.571
# Validation Accuracy |  63.63636363636363  PPV |  [0.875 0.   ]  Recall |  [0.7 0. ]
# Training Epoch 238: | Loss: 0.00638 | Acc: 100.000
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 239: | Loss: 0.06575 | Acc: 98.143
# Validation Accuracy |  66.66666666666666  PPV |  [0.91304348 0.1       ]  Recall |  [0.7        0.33333333]
# Training Epoch 240: | Loss: 0.00141 | Acc: 100.000
# Validation Accuracy |  69.6969696969697  PPV |  [0.91666667 0.11111111]  Recall |  [0.73333333 0.33333333]
# Training Epoch 241: | Loss: 0.02401 | Acc: 99.571
# Validation Accuracy |  66.66666666666666  PPV |  [0.88 0.  ]  Recall |  [0.73333333 0.        ]
# Training Epoch 242: | Loss: 0.01480 | Acc: 99.357
# Validation Accuracy |  75.75757575757575  PPV |  [0.89285714 0.        ]  Recall |  [0.83333333 0.        ]
# Training Epoch 243: | Loss: 0.01224 | Acc: 99.786
# Validation Accuracy |  78.78787878787878  PPV |  [0.92592593 0.16666667]  Recall |  [0.83333333 0.33333333]
# Training Epoch 244: | Loss: 0.02380 | Acc: 99.571
# Validation Accuracy |  84.84848484848484  PPV |  [0.93103448 0.25      ]  Recall |  [0.9        0.33333333]
# Training Epoch 245: | Loss: 0.08284 | Acc: 98.357
# Validation Accuracy |  72.72727272727273  PPV |  [0.92  0.125]  Recall |  [0.76666667 0.33333333]
# Training Epoch 246: | Loss: 0.03413 | Acc: 99.357
# Validation Accuracy |  66.66666666666666  PPV |  [0.91304348 0.1       ]  Recall |  [0.7        0.33333333]
# Training Epoch 247: | Loss: 0.01928 | Acc: 99.143
# Validation Accuracy |  66.66666666666666  PPV |  [0.88 0.  ]  Recall |  [0.73333333 0.        ]
# Training Epoch 248: | Loss: 0.04315 | Acc: 99.357
# Validation Accuracy |  69.6969696969697  PPV |  [0.88461538 0.        ]  Recall |  [0.76666667 0.        ]
# Training Epoch 249: | Loss: 0.00610 | Acc: 100.000
# Validation Accuracy |  69.6969696969697  PPV |  [0.88461538 0.        ]  Recall |  [0.76666667 0.        ]
# Training Epoch 250: | Loss: 0.02426 | Acc: 99.357
# Validation Accuracy |  69.6969696969697  PPV |  [0.88461538 0.        ]  Recall |  [0.76666667 0.        ]

# %%
#Plotting loss
plt.plot(train_loss)
plt.plot(val_loss)
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.axis([0, EPOCHS-1, 0.0, 1.5])
plt.show()

#Plotting Accuracy
plt.plot(train_acc)
plt.plot(val_acc)
plt.title('model accuracy')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train_acc', 'val_acc'], loc='upper left')
plt.axis([0, EPOCHS-1, 0.0, 105])
plt.show()

# %%
y_pred_list = []
test_loader = DataLoader(dataset=test_data, batch_size=1)
model.eval() #Model evaluation
with torch.no_grad():
    for X_batch in test_loader:
        X_batch = X_batch.to(device)
        y_test_pred = model(X_batch)
        y_test_pred = torch.sigmoid(y_test_pred)
        y_pred_tag = torch.round(y_test_pred)
        y_pred_list.append(y_pred_tag.cpu().numpy())

y_pred_list = [a.squeeze().tolist() for a in y_pred_list]
accuracy = accuracy_score(Y_test, y_pred_list)
ppv = precision_score(Y_test, y_pred_list, average=None)
recall = recall_score(Y_test, y_pred_list, average=None)
print("Validation Accuracy | ",accuracy*100," PPV | ",ppv," Recall | ",recall)
cf_matrix = confusion_matrix(Y_test, y_pred_list)
sn.heatmap(cf_matrix, annot=True)
# Out:
# Validation Accuracy |  69.6969696969697  PPV |  [0.88461538 0.        ]  Recall |  [0.76666667 0.        ]
# <AxesSubplot:>

# %%
print(classification_report(Y_test, y_pred_list))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.77      0.82        30
#          1.0       0.00      0.00      0.00         3
#
#     accuracy                           0.70        33
#    macro avg       0.44      0.38      0.41        33
# weighted avg       0.80      0.70      0.75        33

# %%
#Save model once everything is all figured out
